# %%
# !pip install opensignalsreader biosppy peakutils
# Out:
# Requirement already satisfied: opensignalsreader in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: biosppy in /usr/local/lib/python3.12/dist-packages (2.2.4)
# Collecting peakutils
#   Downloading PeakUtils-1.3.5-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from opensignalsreader) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from opensignalsreader) (3.10.0)
# Requirement already satisfied: bidict in /usr/local/lib/python3.12/dist-packages (from biosppy) (0.23.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from biosppy) (3.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.16.3)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.0.13)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.17.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.5.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from biosppy) (4.13.0.92)
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.12/dist-packages (from biosppy) (1.9.0)
# Requirement already satisfied: mock in /usr/local/lib/python3.12/dist-packages (from biosppy) (5.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->opensignalsreader) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->biosppy) (3.6.0)
# Downloading PeakUtils-1.3.5-py3-none-any.whl (7.7 kB)
# Installing collected packages: peakutils
# Successfully installed peakutils-1.3.5

# %%
# Importar librerías
import numpy as np
import matplotlib.pyplot as plt
from opensignalsreader import OpenSignalsReader
from biosppy.signals import ecg
# Ruta del archivo subido
archivo = '/content/E2-D1.txt'

# Leer archivo
ekg = OpenSignalsReader(archivo)

# Extraer señal del canal 2
ekg_signal = ekg.signal(2)

# Frecuencia de muestreo
fs = 1000  # Hz

# Limitar tiempo
idx_10 = int(10 * fs)
idx_30 = int(30 * fs)

# Crear vector de tiempo
tiempo = np.arange(len(ekg_signal)) / fs

tiempo_basal = tiempo[idx_10:idx_30]
ekg_signal_basal = ekg_signal[idx_10:idx_30]

# Procesamiento ECG
ecg_out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada
ekg_filtrado = ecg_out['filtered']

# FFT
ekg_centrado = ekg_filtrado - np.mean(ekg_filtrado)
freq_basal = np.fft.rfftfreq(len(ekg_filtrado), d=1/fs)
esp_basal = np.abs(np.fft.rfft(ekg_centrado))

# --------- Plot dominio del tiempo ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado)
plt.title('Señal ECG Filtrada - Dominio del Tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- FFT ----------
plt.figure(figsize=(15,5))
plt.plot(freq_basal, esp_basal)
plt.title('Dominio de la Frecuencia')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Magnitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- Plot ECG estilo milimétrico ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, linewidth=1)

plt.xlim(10,14)

# Cuadrícula tipo papel ECG
plt.minorticks_on()
plt.grid(which='major', color='red', linestyle='-', linewidth=0.8, alpha=0.6)
plt.grid(which='minor', color='pink', linestyle='-', linewidth=0.5, alpha=0.7)

# Escala milimétrica típica ECG:
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.04))  # 1 mm = 0.04 s
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(0.20))  # 5 mm = 0.20 s

# Ajuste vertical aproximado (depende de calibración real)
ymin, ymax = plt.ylim()
yrange = ymax - ymin
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(yrange/25))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(yrange/5))

plt.title('ECG Normalizado en Papel Milimétrico')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.tight_layout()
plt.show()

# Procesamiento ECG
out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada y picos R
ekg_filtrado = out['filtered']
rpeaks = out['rpeaks']

# Graficar con picos
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, label='ECG Filtrado')
plt.scatter(
    tiempo_basal[rpeaks],
    ekg_filtrado[rpeaks],
    color='red',
    label='Picos R',
    zorder=3
)

plt.title('ECG con detección de picos R')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Tiempos de picos R
tiempos_r = tiempo_basal[rpeaks]

# Intervalos RR y frecuencia cardíaca
rr_intervals = np.diff(tiempos_r)
hr = 60 / rr_intervals
hr_promedio = np.mean(hr)

print(f'Frecuencia cardíaca promedio: {hr_promedio:.2f} BPM')
# Out:
# Frecuencia cardíaca promedio: 139.58 BPM

# %%
# Ruta del archivo subido
archivo = '/content/E2-D2.txt'

# Leer archivo
ekg = OpenSignalsReader(archivo)

# Extraer señal del canal 2
ekg_signal = ekg.signal(2)

# Frecuencia de muestreo
fs = 1000  # Hz

# Limitar tiempo
idx_10 = int(10 * fs)
idx_30 = int(30 * fs)

# Crear vector de tiempo
tiempo = np.arange(len(ekg_signal)) / fs

tiempo_basal = tiempo[idx_10:idx_30]
ekg_signal_basal = ekg_signal[idx_10:idx_30]

# Procesamiento ECG
ecg_out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada
ekg_filtrado = ecg_out['filtered']

# FFT
ekg_centrado = ekg_filtrado - np.mean(ekg_filtrado)
freq_basal = np.fft.rfftfreq(len(ekg_filtrado), d=1/fs)
esp_basal = np.abs(np.fft.rfft(ekg_centrado))

# --------- Plot dominio del tiempo ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado)
plt.title('Señal ECG Filtrada - Dominio del Tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- FFT ----------
plt.figure(figsize=(15,5))
plt.plot(freq_basal, esp_basal)
plt.title('Dominio de la Frecuencia')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Magnitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- Plot ECG estilo milimétrico ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, linewidth=1)

plt.xlim(10,14)

# Cuadrícula tipo papel ECG
plt.minorticks_on()
plt.grid(which='major', color='red', linestyle='-', linewidth=0.8, alpha=0.6)
plt.grid(which='minor', color='pink', linestyle='-', linewidth=0.5, alpha=0.7)

# Escala milimétrica típica ECG:
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.04))  # 1 mm = 0.04 s
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(0.20))  # 5 mm = 0.20 s

# Ajuste vertical aproximado (depende de calibración real)
ymin, ymax = plt.ylim()
yrange = ymax - ymin
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(yrange/25))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(yrange/5))

plt.title('ECG Normalizado en Papel Milimétrico')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.tight_layout()
plt.show()

# Procesamiento ECG
out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada y picos R
ekg_filtrado = out['filtered']
rpeaks = out['rpeaks']

# Graficar con picos
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, label='ECG Filtrado')
plt.scatter(
    tiempo_basal[rpeaks],
    ekg_filtrado[rpeaks],
    color='red',
    label='Picos R',
    zorder=3
)

plt.title('ECG con detección de picos R')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Tiempos de picos R
tiempos_r = tiempo_basal[rpeaks]

# Intervalos RR y frecuencia cardíaca
rr_intervals = np.diff(tiempos_r)
hr = 60 / rr_intervals
hr_promedio = np.mean(hr)

print(f'Frecuencia cardíaca promedio: {hr_promedio:.2f} BPM')
# Out:
# Frecuencia cardíaca promedio: 121.53 BPM

# %%
# Ruta del archivo subido
archivo = '/content/E2-D3.txt'

# Leer archivo
ekg = OpenSignalsReader(archivo)

# Extraer señal del canal 2
ekg_signal = ekg.signal(2)

# Frecuencia de muestreo
fs = 1000  # Hz

# Limitar tiempo
idx_10 = int(10 * fs)
idx_30 = int(30 * fs)

# Crear vector de tiempo
tiempo = np.arange(len(ekg_signal)) / fs

tiempo_basal = tiempo[idx_10:idx_30]
ekg_signal_basal = ekg_signal[idx_10:idx_30]

# Procesamiento ECG
ecg_out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada
ekg_filtrado = ecg_out['filtered']

# FFT
ekg_centrado = ekg_filtrado - np.mean(ekg_filtrado)
freq_basal = np.fft.rfftfreq(len(ekg_filtrado), d=1/fs)
esp_basal = np.abs(np.fft.rfft(ekg_centrado))

# --------- Plot dominio del tiempo ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado)
plt.title('Señal ECG Filtrada - Dominio del Tiempo')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- FFT ----------
plt.figure(figsize=(15,5))
plt.plot(freq_basal, esp_basal)
plt.title('Dominio de la Frecuencia')
plt.xlabel('Frecuencia (Hz)')
plt.ylabel('Magnitud')
plt.grid(True)
plt.tight_layout()
plt.show()

# --------- Plot ECG estilo milimétrico ----------
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, linewidth=1)

plt.xlim(10,14)

# Cuadrícula tipo papel ECG
plt.minorticks_on()
plt.grid(which='major', color='red', linestyle='-', linewidth=0.8, alpha=0.6)
plt.grid(which='minor', color='pink', linestyle='-', linewidth=0.5, alpha=0.7)

# Escala milimétrica típica ECG:
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(0.04))  # 1 mm = 0.04 s
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(0.20))  # 5 mm = 0.20 s

# Ajuste vertical aproximado (depende de calibración real)
ymin, ymax = plt.ylim()
yrange = ymax - ymin
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(yrange/25))
plt.gca().yaxis.set_major_locator(plt.MultipleLocator(yrange/5))

plt.title('ECG Normalizado en Papel Milimétrico')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.tight_layout()
plt.show()

# Procesamiento ECG
out = ecg.ecg(signal=ekg_signal_basal, sampling_rate=fs, show=False)

# Señal filtrada y picos R
ekg_filtrado = out['filtered']
rpeaks = out['rpeaks']

# Graficar con picos
plt.figure(figsize=(15,5))
plt.plot(tiempo_basal, ekg_filtrado, label='ECG Filtrado')
plt.scatter(
    tiempo_basal[rpeaks],
    ekg_filtrado[rpeaks],
    color='red',
    label='Picos R',
    zorder=3
)

plt.title('ECG con detección de picos R')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Tiempos de picos R
tiempos_r = tiempo_basal[rpeaks]

# Intervalos RR y frecuencia cardíaca
rr_intervals = np.diff(tiempos_r)
hr = 60 / rr_intervals
hr_promedio = np.mean(hr)

print(f'Frecuencia cardíaca promedio: {hr_promedio:.2f} BPM')
# Out:
# Frecuencia cardíaca promedio: 115.59 BPM
